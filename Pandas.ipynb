# %%
import pandas as pd
import time

# ------------------------------
# Function: Summarize Dataset
# ------------------------------
def summarize_dataset(df, label):
    print(f"\n📊 Summary Report for: {label}")

    # General numeric and non-numeric stats
    print("\n📈 Descriptive Statistics:")
    print(df.describe(include='all'))

    # Count of unique values per column
    print("\n🔍 Unique Values per Column:")
    print(df.nunique())

    # Most frequent values for object/text columns
    print("\n🏷️ Top 3 Most Frequent Values (Text Columns):")
    for column in df.select_dtypes(include='object').columns:
        print(f"\n{column}:\n{df[column].value_counts().head(3)}")


# ------------------------------
# Function: Analyze Selected Columns
# ------------------------------
def analyze_shared_columns(df, dataset_name, shared_fields):
    print(f"\n📘 Analyzing Shared Columns in: {dataset_name}")
    subset = df[shared_fields]

    # Numeric summary stats
    print("\n📈 Numeric Summary (mean, median, min, max, std):")
    print(subset.describe().T[['mean', '50%', 'min', 'max', 'std']])

    # Count of unique values
    print("\n🔍 Unique Value Counts:")
    print(subset.nunique())

    # Most frequent values
    print("\n🏷️ Top 3 Frequent Entries:")
    for field in shared_fields:
        print(f"• {field}:\n{subset[field].value_counts().head(3)}\n")


# ------------------------------
# Main Dataset Paths
# ------------------------------
data_sources = {
    "Facebook Ads": "2024_fb_ads_president_scored_anon.csv",
    "Facebook Posts": "2024_fb_posts_president_scored_anon.csv",
    "Twitter Posts": "2024_tw_posts_president_scored_anon.csv"
}

# Shared indicator columns across all datasets (Illuminating Project)
shared_indicators = [
    'advocacy_msg_type_illuminating', 'attack_msg_type_illuminating',
    'covid_topic_illuminating', 'cta_msg_type_illuminating',
    'economy_topic_illuminating', 'education_topic_illuminating',
    'engagement_cta_subtype_illuminating', 'environment_topic_illuminating',
    'foreign_policy_topic_illuminating', 'fraud_illuminating',
    'freefair_illuminating', 'fundraising_cta_subtype_illuminating',
    'governance_topic_illuminating', 'health_topic_illuminating',
    'image_msg_type_illuminating', 'immigration_topic_illuminating',
    'incivility_illuminating', 'issue_msg_type_illuminating',
    'lgbtq_issues_topic_illuminating', 'military_topic_illuminating',
    'race_and_ethnicity_topic_illuminating', 'safety_topic_illuminating',
    'scam_illuminating', 'social_and_cultural_topic_illuminating',
    'technology_and_privacy_topic_illuminating', 'voting_cta_subtype_illuminating',
    'womens_issue_topic_illuminating'
]

# ------------------------------
# Process All Main Datasets
# ------------------------------
for name, file_path in data_sources.items():
    df = pd.read_csv(file_path)
    summarize_dataset(df, name)
    analyze_shared_columns(df, name, shared_indicators)


# ------------------------------
# Bonus Dataset: Trump Truths
# ------------------------------
print("\n🧾 Bonus Analysis: Trump Truths Dataset")
start = time.time()

trump_df = pd.read_csv("Downloads/period_03/trump_truths_dataset.csv")
summarize_dataset(trump_df, "Trump Truths")

end = time.time()
print(f"\n⏱️ Total Time Taken: {end - start:.2f} seconds")
# Out:
# 📊 Summary Report for: Facebook Ads
#
# 📈 Descriptive Statistics:
#                                                   page_id  \
# count                                              246745
# unique                                               4475
# top     4d66f5853f0365dba032a87704a634f023d15babde973b...
# freq                                                55503
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                              246745           246745
# unique                                             246745              547
# top     0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9...       2024-10-27
# freq                                                    1             8619
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                      bylines currency delivery_by_region  \
# count                 245736   246745             246745
# unique                  3790       18             141122
# top     HARRIS FOR PRESIDENT      USD                 {}
# freq                   49788   246599              30989
# mean                     NaN      NaN                NaN
# std                      NaN      NaN                NaN
# min                      NaN      NaN                NaN
# 25%                      NaN      NaN                NaN
# 50%                      NaN      NaN                NaN
# 75%                      NaN      NaN                NaN
# max                      NaN      NaN                NaN
#
#        demographic_distribution  estimated_audience_size  \
# count                    246745             2.467450e+05
# unique                   215622                      NaN
# top                          {}                      NaN
# freq                      30989                      NaN
# mean                        NaN             5.564629e+05
# std                         NaN             4.098648e+05
# min                         NaN             0.000000e+00
# 25%                         NaN             7.500000e+04
# 50%                         NaN             3.000000e+05
# 75%                         NaN             1.000001e+06
# max                         NaN             1.000001e+06
#
#         estimated_impressions  estimated_spend  ...  \
# count           246745.000000    246745.000000  ...
# unique                    NaN              NaN  ...
# top                       NaN              NaN  ...
# freq                      NaN              NaN  ...
# mean             45601.525952      1061.291434  ...
# std             136790.769901      4992.560749  ...
# min                499.000000        49.000000  ...
# 25%                499.000000        49.000000  ...
# 50%               3499.000000        49.000000  ...
# 75%              22499.000000       449.000000  ...
# max            1000000.000000    474999.000000  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                    246745.000000               246745.000000
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                          0.003230                    0.002176
# std                           0.056742                    0.046601
# min                           0.000000                    0.000000
# 25%                           0.000000                    0.000000
# 50%                           0.000000                    0.000000
# 75%                           0.000000                    0.000000
# max                           1.000000                    1.000000
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                          246745.000000              246745.000000
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                0.012434                   0.033723
# std                                 0.110812                   0.180516
# min                                 0.000000                   0.000000
# 25%                                 0.000000                   0.000000
# 50%                                 0.000000                   0.000000
# 75%                                 0.000000                   0.000000
# max                                 1.000000                   1.000000
#
#         social_and_cultural_topic_illuminating  \
# count                            246745.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                  0.105838
# std                                   0.307631
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#         technology_and_privacy_topic_illuminating  \
# count                               246745.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                     0.001155
# std                                      0.033966
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                     246745.000000            246745.000000
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                           0.080909                 0.187526
# std                            0.272697                 0.390334
# min                            0.000000                 0.000000
# 25%                            0.000000                 0.000000
# 50%                            0.000000                 0.000000
# 75%                            0.000000                 0.000000
# max                            1.000000                 1.000000
#
#         freefair_illuminating  fraud_illuminating
# count           246745.000000       246745.000000
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                 0.006416            0.002638
# std                  0.079840            0.051297
# min                  0.000000            0.000000
# 25%                  0.000000            0.000000
# 50%                  0.000000            0.000000
# 75%                  0.000000            0.000000
# max                  1.000000            1.000000
#
# [11 rows x 41 columns]
#
# 🔍 Unique Values per Column:
# page_id                                        4475
# ad_id                                        246745
# ad_creation_time                                547
# bylines                                        3790
# currency                                         18
# delivery_by_region                           141122
# demographic_distribution                     215622
# estimated_audience_size                           9
# estimated_impressions                            39
# estimated_spend                                  44
# publisher_platforms                               9
# illuminating_scored_message                   26338
# illuminating_mentions                           278
# scam_illuminating                                 2
# election_integrity_Truth_illuminating             2
# advocacy_msg_type_illuminating                    2
# issue_msg_type_illuminating                       2
# attack_msg_type_illuminating                      2
# image_msg_type_illuminating                       2
# cta_msg_type_illuminating                         2
# engagement_cta_subtype_illuminating               2
# fundraising_cta_subtype_illuminating              2
# voting_cta_subtype_illuminating                   2
# covid_topic_illuminating                          2
# economy_topic_illuminating                        2
# education_topic_illuminating                      2
# environment_topic_illuminating                    2
# foreign_policy_topic_illuminating                 2
# governance_topic_illuminating                     2
# health_topic_illuminating                         2
# immigration_topic_illuminating                    2
# lgbtq_issues_topic_illuminating                   2
# military_topic_illuminating                       2
# race_and_ethnicity_topic_illuminating             2
# safety_topic_illuminating                         2
# social_and_cultural_topic_illuminating            2
# technology_and_privacy_topic_illuminating         2
# womens_issue_topic_illuminating                   2
# incivility_illuminating                           2
# freefair_illuminating                             2
# fraud_illuminating                                2
# dtype: int64
#
# 🏷️ Top 3 Most Frequent Values (Text Columns):
#
# page_id:
# page_id
# 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d    55503
# e3342051b60393770363ffc02946a0f76bc3e4155190d1f05fb0277b34bf6480    23988
# 4ade404186269ec62d2dd7d9e0ed5f93a5f32c057516879d627ea9fbd628ef9b    14822
# Name: count, dtype: int64
#
# ad_id:
# ad_id
# 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc    1
# 329368f2aa4e55f382777eeb9076b6dc15d27129adc7546a6c2366c1294820d9    1
# 2c055606917671911ca27cd4a152aea8294c227696bbfc8c7110c979369e7987    1
# Name: count, dtype: int64
#
# ad_creation_time:
# ad_creation_time
# 2024-10-27    8619
# 2024-10-28    7356
# 2024-10-26    6414
# Name: count, dtype: int64
#
# bylines:
# bylines
# HARRIS FOR PRESIDENT    49788
# HARRIS VICTORY FUND     32612
# BIDEN VICTORY FUND      15539
# Name: count, dtype: int64
#
# currency:
# currency
# USD    246599
# INR        63
# GBP        17
# Name: count, dtype: int64
#
# delivery_by_region:
# delivery_by_region
# {}                                                30989
# {'Georgia': {'spend': 49, 'impressions': 499}}     2307
# {'Arizona': {'spend': 49, 'impressions': 499}}     2020
# Name: count, dtype: int64
#
# demographic_distribution:
# demographic_distribution
# {}                                                   30989
# {'female_65+': {'spend': 49, 'impressions': 499}}       44
# {'male_65+': {'spend': 49, 'impressions': 499}}         24
# Name: count, dtype: int64
#
# publisher_platforms:
# publisher_platforms
# ['facebook', 'instagram']    214434
# ['facebook']                  23259
# ['instagram']                  8395
# Name: count, dtype: int64
#
# illuminating_scored_message:
# illuminating_scored_message
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855    5972
# 82459467ad44f717f2089911f5210cce1ff025dc0cee03bdb2e60da827edb282    1887
# 3b1d236346df93fd259a23d523f6deeed9b9939158b6f34b11854ea0f97ef35d    1352
# Name: count, dtype: int64
#
# illuminating_mentions:
# illuminating_mentions
# []                   73205
# ['Donald Trump']     53182
# ['Kamala Harris']    31019
# Name: count, dtype: int64
#
# 📘 Analyzing Shared Columns in: Facebook Ads
#
# 📈 Numeric Summary (mean, median, min, max, std):
#                                                mean  50%  min  max       std
# advocacy_msg_type_illuminating             0.548631  1.0  0.0  1.0  0.497630
# attack_msg_type_illuminating               0.271856  0.0  0.0  1.0  0.444917
# covid_topic_illuminating                   0.024876  0.0  0.0  1.0  0.155747
# cta_msg_type_illuminating                  0.572769  1.0  0.0  1.0  0.494677
# economy_topic_illuminating                 0.122122  0.0  0.0  1.0  0.327427
# education_topic_illuminating               0.014327  0.0  0.0  1.0  0.118833
# engagement_cta_subtype_illuminating        0.124870  0.0  0.0  1.0  0.330572
# environment_topic_illuminating             0.021249  0.0  0.0  1.0  0.144212
# foreign_policy_topic_illuminating          0.005265  0.0  0.0  1.0  0.072366
# fraud_illuminating                         0.002638  0.0  0.0  1.0  0.051297
# freefair_illuminating                      0.006416  0.0  0.0  1.0  0.079840
# fundraising_cta_subtype_illuminating       0.228487  0.0  0.0  1.0  0.419859
# governance_topic_illuminating              0.025642  0.0  0.0  1.0  0.158065
# health_topic_illuminating                  0.109190  0.0  0.0  1.0  0.311878
# image_msg_type_illuminating                0.222704  0.0  0.0  1.0  0.416062
# immigration_topic_illuminating             0.033569  0.0  0.0  1.0  0.180118
# incivility_illuminating                    0.187526  0.0  0.0  1.0  0.390334
# issue_msg_type_illuminating                0.381649  0.0  0.0  1.0  0.485792
# lgbtq_issues_topic_illuminating            0.003230  0.0  0.0  1.0  0.056742
# military_topic_illuminating                0.002176  0.0  0.0  1.0  0.046601
# race_and_ethnicity_topic_illuminating      0.012434  0.0  0.0  1.0  0.110812
# safety_topic_illuminating                  0.033723  0.0  0.0  1.0  0.180516
# scam_illuminating                          0.071633  0.0  0.0  1.0  0.257879
# social_and_cultural_topic_illuminating     0.105838  0.0  0.0  1.0  0.307631
# technology_and_privacy_topic_illuminating  0.001155  0.0  0.0  1.0  0.033966
# voting_cta_subtype_illuminating            0.143845  0.0  0.0  1.0  0.350933
# womens_issue_topic_illuminating            0.080909  0.0  0.0  1.0  0.272697
#
# 🔍 Unique Value Counts:
# advocacy_msg_type_illuminating               2
# attack_msg_type_illuminating                 2
# covid_topic_illuminating                     2
# cta_msg_type_illuminating                    2
# economy_topic_illuminating                   2
# education_topic_illuminating                 2
# engagement_cta_subtype_illuminating          2
# environment_topic_illuminating               2
# foreign_policy_topic_illuminating            2
# fraud_illuminating                           2
# freefair_illuminating                        2
# fundraising_cta_subtype_illuminating         2
# governance_topic_illuminating                2
# health_topic_illuminating                    2
# image_msg_type_illuminating                  2
# immigration_topic_illuminating               2
# incivility_illuminating                      2
# issue_msg_type_illuminating                  2
# lgbtq_issues_topic_illuminating              2
# military_topic_illuminating                  2
# race_and_ethnicity_topic_illuminating        2
# safety_topic_illuminating                    2
# scam_illuminating                            2
# social_and_cultural_topic_illuminating       2
# technology_and_privacy_topic_illuminating    2
# voting_cta_subtype_illuminating              2
# womens_issue_topic_illuminating              2
# dtype: int64
#
# 🏷️ Top 3 Frequent Entries:
# • advocacy_msg_type_illuminating:
# advocacy_msg_type_illuminating
# 1    135372
# 0    111373
# Name: count, dtype: int64
#
# • attack_msg_type_illuminating:
# attack_msg_type_illuminating
# 0    179666
# 1     67079
# Name: count, dtype: int64
#
# • covid_topic_illuminating:
# covid_topic_illuminating
# 0    240607
# 1      6138
# Name: count, dtype: int64
#
# • cta_msg_type_illuminating:
# cta_msg_type_illuminating
# 1    141328
# 0    105417
# Name: count, dtype: int64
#
# • economy_topic_illuminating:
# economy_topic_illuminating
# 0    216612
# 1     30133
# Name: count, dtype: int64
#
# • education_topic_illuminating:
# education_topic_illuminating
# 0    243210
# 1      3535
# Name: count, dtype: int64
#
# • engagement_cta_subtype_illuminating:
# engagement_cta_subtype_illuminating
# 0    215934
# 1     30811
# Name: count, dtype: int64
#
# • environment_topic_illuminating:
# environment_topic_illuminating
# 0    241502
# 1      5243
# Name: count, dtype: int64
#
# • foreign_policy_topic_illuminating:
# foreign_policy_topic_illuminating
# 0    245446
# 1      1299
# Name: count, dtype: int64
#
# • fraud_illuminating:
# fraud_illuminating
# 0    246094
# 1       651
# Name: count, dtype: int64
#
# • freefair_illuminating:
# freefair_illuminating
# 0    245162
# 1      1583
# Name: count, dtype: int64
#
# • fundraising_cta_subtype_illuminating:
# fundraising_cta_subtype_illuminating
# 0    190367
# 1     56378
# Name: count, dtype: int64
#
# • governance_topic_illuminating:
# governance_topic_illuminating
# 0    240418
# 1      6327
# Name: count, dtype: int64
#
# • health_topic_illuminating:
# health_topic_illuminating
# 0    219803
# 1     26942
# Name: count, dtype: int64
#
# • image_msg_type_illuminating:
# image_msg_type_illuminating
# 0    191794
# 1     54951
# Name: count, dtype: int64
#
# • immigration_topic_illuminating:
# immigration_topic_illuminating
# 0    238462
# 1      8283
# Name: count, dtype: int64
#
# • incivility_illuminating:
# incivility_illuminating
# 0    200474
# 1     46271
# Name: count, dtype: int64
#
# • issue_msg_type_illuminating:
# issue_msg_type_illuminating
# 0    152575
# 1     94170
# Name: count, dtype: int64
#
# • lgbtq_issues_topic_illuminating:
# lgbtq_issues_topic_illuminating
# 0    245948
# 1       797
# Name: count, dtype: int64
#
# • military_topic_illuminating:
# military_topic_illuminating
# 0    246208
# 1       537
# Name: count, dtype: int64
#
# • race_and_ethnicity_topic_illuminating:
# race_and_ethnicity_topic_illuminating
# 0    243677
# 1      3068
# Name: count, dtype: int64
#
# • safety_topic_illuminating:
# safety_topic_illuminating
# 0    238424
# 1      8321
# Name: count, dtype: int64
#
# • scam_illuminating:
# scam_illuminating
# 0    229070
# 1     17675
# Name: count, dtype: int64
#
# • social_and_cultural_topic_illuminating:
# social_and_cultural_topic_illuminating
# 0    220630
# 1     26115
# Name: count, dtype: int64
#
# • technology_and_privacy_topic_illuminating:
# technology_and_privacy_topic_illuminating
# 0    246460
# 1       285
# Name: count, dtype: int64
#
# • voting_cta_subtype_illuminating:
# voting_cta_subtype_illuminating
# 0    211252
# 1     35493
# Name: count, dtype: int64
#
# • womens_issue_topic_illuminating:
# womens_issue_topic_illuminating
# 0    226781
# 1     19964
# Name: count, dtype: int64
#
#
# 📊 Summary Report for: Facebook Posts
#
# 📈 Descriptive Statistics:
#                                               Facebook_Id  \
# count                                               19009
# unique                                                 21
# top     32fc18da91029ff09bf74fe9887eace6b5d2145809d583...
# freq                                                 9013
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   post_id Page Category  \
# count                                               19009         16537
# unique                                              19009             6
# top     8570b69695e00d8f06b12398ed525497e1712b5369c6fc...        PERSON
# freq                                                    1          9453
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#        Page Admin Top Country              Post Created Post Created Date  \
# count                   16280                     19009             19009
# unique                      1                     18951               425
# top                        US  2024-09-30T13:47:21.000Z        2024-10-31
# freq                    16280                         2               103
# mean                      NaN                       NaN               NaN
# std                       NaN                       NaN               NaN
# min                       NaN                       NaN               NaN
# 25%                       NaN                       NaN               NaN
# 50%                       NaN                       NaN               NaN
# 75%                       NaN                       NaN               NaN
# max                       NaN                       NaN               NaN
#
#        Post Created Time   Type Total Interactions          Likes  ...  \
# count              19009  16544              19009   19009.000000  ...
# unique             16102      9               5665            NaN  ...
# top             17:30:01   Link                 15            NaN  ...
# freq                   7   7404                115            NaN  ...
# mean                 NaN    NaN                NaN    2377.695407  ...
# std                  NaN    NaN                NaN   11253.469669  ...
# min                  NaN    NaN                NaN       0.000000  ...
# 25%                  NaN    NaN                NaN      31.000000  ...
# 50%                  NaN    NaN                NaN     139.000000  ...
# 75%                  NaN    NaN                NaN     738.000000  ...
# max                  NaN    NaN                NaN  351979.000000  ...
#
#         military_topic_illuminating  race_and_ethnicity_topic_illuminating  \
# count                  19009.000000                           19009.000000
# unique                          NaN                                    NaN
# top                             NaN                                    NaN
# freq                            NaN                                    NaN
# mean                       0.005576                               0.021569
# std                        0.074468                               0.145274
# min                        0.000000                               0.000000
# 25%                        0.000000                               0.000000
# 50%                        0.000000                               0.000000
# 75%                        0.000000                               0.000000
# max                        1.000000                               1.000000
#
#         safety_topic_illuminating  social_and_cultural_topic_illuminating  \
# count                19009.000000                            19009.000000
# unique                        NaN                                     NaN
# top                           NaN                                     NaN
# freq                          NaN                                     NaN
# mean                     0.032195                                0.061708
# std                      0.176523                                0.240630
# min                      0.000000                                0.000000
# 25%                      0.000000                                0.000000
# 50%                      0.000000                                0.000000
# 75%                      0.000000                                0.000000
# max                      1.000000                                1.000000
#
#         technology_and_privacy_topic_illuminating  \
# count                                19009.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                     0.002052
# std                                      0.045250
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                      19009.000000             19009.000000
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                           0.025462                 0.127887
# std                            0.157527                 0.333972
# min                            0.000000                 0.000000
# 25%                            0.000000                 0.000000
# 50%                            0.000000                 0.000000
# 75%                            0.000000                 0.000000
# max                            1.000000                 1.000000
#
#         scam_illuminating freefair_illuminating fraud_illuminating
# count        18060.000000          19009.000000       19009.000000
# unique                NaN                   NaN                NaN
# top                   NaN                   NaN                NaN
# freq                  NaN                   NaN                NaN
# mean             0.020210              0.002841           0.008627
# std              0.140723              0.053224           0.092485
# min              0.000000              0.000000           0.000000
# 25%              0.000000              0.000000           0.000000
# 50%              0.000000              0.000000           0.000000
# 75%              0.000000              0.000000           0.000000
# max              1.000000              1.000000           1.000000
#
# [11 rows x 56 columns]
#
# 🔍 Unique Values per Column:
# Facebook_Id                                                            21
# post_id                                                             19009
# Page Category                                                           6
# Page Admin Top Country                                                  1
# Post Created                                                        18951
# Post Created Date                                                     425
# Post Created Time                                                   16102
# Type                                                                    9
# Total Interactions                                                   5665
# Likes                                                                4118
# Comments                                                             3075
# Shares                                                               1840
# Love                                                                 1600
# Wow                                                                   194
# Haha                                                                 1154
# Sad                                                                   239
# Angry                                                                 423
# Care                                                                  513
# Video Share Status                                                      3
# Is Video Owner?                                                         3
# Post Views                                                           2842
# Total Views                                                          2901
# Total Views For All Crossposts                                         73
# Video Length                                                          774
# Sponsor Id                                                              0
# Sponsor Name                                                            0
# Sponsor Category                                                        0
# Overperforming Score                                                 2007
# illuminating_scored_messageelection_integrity_Truth_illuminating        0
# advocacy_msg_type_illuminating                                          2
# issue_msg_type_illuminating                                             2
# attack_msg_type_illuminating                                            2
# image_msg_type_illuminating                                             2
# cta_msg_type_illuminating                                               2
# engagement_cta_subtype_illuminating                                     2
# fundraising_cta_subtype_illuminating                                    2
# voting_cta_subtype_illuminating                                         2
# covid_topic_illuminating                                                2
# economy_topic_illuminating                                              2
# education_topic_illuminating                                            2
# environment_topic_illuminating                                          2
# foreign_policy_topic_illuminating                                       2
# governance_topic_illuminating                                           2
# health_topic_illuminating                                               2
# immigration_topic_illuminating                                          2
# lgbtq_issues_topic_illuminating                                         2
# military_topic_illuminating                                             2
# race_and_ethnicity_topic_illuminating                                   2
# safety_topic_illuminating                                               2
# social_and_cultural_topic_illuminating                                  2
# technology_and_privacy_topic_illuminating                               2
# womens_issue_topic_illuminating                                         2
# incivility_illuminating                                                 2
# scam_illuminating                                                       2
# freefair_illuminating                                                   2
# fraud_illuminating                                                      2
# dtype: int64
#
# 🏷️ Top 3 Most Frequent Values (Text Columns):
#
# Facebook_Id:
# Facebook_Id
# 32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064    9013
# bfe51c6ac2cab17ba5c85883e76f61398031ed57e4cf62d19fd483548ebb904b    1431
# ac24f31c4d4b3d5555065fa9558bdca4ab4b5e1379922875ae9e6e32f1d46d25    1231
# Name: count, dtype: int64
#
# post_id:
# post_id
# 8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138    1
# c94dbf5aeb84cc37a4d35892dc9b2154f6ea86b181e896dfe8dd87c3e34c5558    1
# ab139678dcef59090a9f96b76980050d3a1ea4922a43e1695863ecb00212008f    1
# Name: count, dtype: int64
#
# Page Category:
# Page Category
# PERSON        9453
# ACTOR         3304
# POLITICIAN    2595
# Name: count, dtype: int64
#
# Page Admin Top Country:
# Page Admin Top Country
# US    16280
# Name: count, dtype: int64
#
# Post Created:
# Post Created
# 2024-09-30T13:47:21.000Z    2
# 2024-10-31T16:05:19.000Z    2
# 2024-10-30T15:21:40.000Z    2
# Name: count, dtype: int64
#
# Post Created Date:
# Post Created Date
# 2024-10-31    103
# 2024-01-10    102
# 2024-01-15     96
# Name: count, dtype: int64
#
# Post Created Time:
# Post Created Time
# 17:30:01    7
# 19:42:00    7
# 19:30:02    6
# Name: count, dtype: int64
#
# Type:
# Type
# Link            7404
# Photo           3820
# Native Video    2931
# Name: count, dtype: int64
#
# Total Interactions:
# Total Interactions
# 15    115
# 23    115
# 26    113
# Name: count, dtype: int64
#
# Video Share Status:
# Video Share Status
# owned        3100
# share          99
# crosspost      72
# Name: count, dtype: int64
#
# Is Video Owner?:
# Is Video Owner?
# -      13280
# Yes     3181
# No        83
# Name: count, dtype: int64
#
# Video Length:
# Video Length
# 00:00:30    83
# 00:01:00    50
# 00:00:59    37
# Name: count, dtype: int64
#
# 📘 Analyzing Shared Columns in: Facebook Posts
#
# 📈 Numeric Summary (mean, median, min, max, std):
#                                                mean  50%  min  max       std
# advocacy_msg_type_illuminating             0.549266  1.0  0.0  1.0  0.497580
# attack_msg_type_illuminating               0.216687  0.0  0.0  1.0  0.411998
# covid_topic_illuminating                   0.052396  0.0  0.0  1.0  0.222831
# cta_msg_type_illuminating                  0.132832  0.0  0.0  1.0  0.339402
# economy_topic_illuminating                 0.090378  0.0  0.0  1.0  0.286730
# education_topic_illuminating               0.014993  0.0  0.0  1.0  0.121527
# engagement_cta_subtype_illuminating        0.090852  0.0  0.0  1.0  0.287406
# environment_topic_illuminating             0.022253  0.0  0.0  1.0  0.147508
# foreign_policy_topic_illuminating          0.036877  0.0  0.0  1.0  0.188465
# fraud_illuminating                         0.008627  0.0  0.0  1.0  0.092485
# freefair_illuminating                      0.002841  0.0  0.0  1.0  0.053224
# fundraising_cta_subtype_illuminating       0.018412  0.0  0.0  1.0  0.134441
# governance_topic_illuminating              0.031091  0.0  0.0  1.0  0.173567
# health_topic_illuminating                  0.048661  0.0  0.0  1.0  0.215164
# image_msg_type_illuminating                0.148561  0.0  0.0  1.0  0.355665
# immigration_topic_illuminating             0.040823  0.0  0.0  1.0  0.197885
# incivility_illuminating                    0.127887  0.0  0.0  1.0  0.333972
# issue_msg_type_illuminating                0.460308  0.0  0.0  1.0  0.498435
# lgbtq_issues_topic_illuminating            0.003367  0.0  0.0  1.0  0.057928
# military_topic_illuminating                0.005576  0.0  0.0  1.0  0.074468
# race_and_ethnicity_topic_illuminating      0.021569  0.0  0.0  1.0  0.145274
# safety_topic_illuminating                  0.032195  0.0  0.0  1.0  0.176523
# scam_illuminating                          0.020210  0.0  0.0  1.0  0.140723
# social_and_cultural_topic_illuminating     0.061708  0.0  0.0  1.0  0.240630
# technology_and_privacy_topic_illuminating  0.002052  0.0  0.0  1.0  0.045250
# voting_cta_subtype_illuminating            0.023410  0.0  0.0  1.0  0.151206
# womens_issue_topic_illuminating            0.025462  0.0  0.0  1.0  0.157527
#
# 🔍 Unique Value Counts:
# advocacy_msg_type_illuminating               2
# attack_msg_type_illuminating                 2
# covid_topic_illuminating                     2
# cta_msg_type_illuminating                    2
# economy_topic_illuminating                   2
# education_topic_illuminating                 2
# engagement_cta_subtype_illuminating          2
# environment_topic_illuminating               2
# foreign_policy_topic_illuminating            2
# fraud_illuminating                           2
# freefair_illuminating                        2
# fundraising_cta_subtype_illuminating         2
# governance_topic_illuminating                2
# health_topic_illuminating                    2
# image_msg_type_illuminating                  2
# immigration_topic_illuminating               2
# incivility_illuminating                      2
# issue_msg_type_illuminating                  2
# lgbtq_issues_topic_illuminating              2
# military_topic_illuminating                  2
# race_and_ethnicity_topic_illuminating        2
# safety_topic_illuminating                    2
# scam_illuminating                            2
# social_and_cultural_topic_illuminating       2
# technology_and_privacy_topic_illuminating    2
# voting_cta_subtype_illuminating              2
# womens_issue_topic_illuminating              2
# dtype: int64
#
# 🏷️ Top 3 Frequent Entries:
# • advocacy_msg_type_illuminating:
# advocacy_msg_type_illuminating
# 1    10441
# 0     8568
# Name: count, dtype: int64
#
# • attack_msg_type_illuminating:
# attack_msg_type_illuminating
# 0    14890
# 1     4119
# Name: count, dtype: int64
#
# • covid_topic_illuminating:
# covid_topic_illuminating
# 0    18013
# 1      996
# Name: count, dtype: int64
#
# • cta_msg_type_illuminating:
# cta_msg_type_illuminating
# 0    16484
# 1     2525
# Name: count, dtype: int64
#
# • economy_topic_illuminating:
# economy_topic_illuminating
# 0    17291
# 1     1718
# Name: count, dtype: int64
#
# • education_topic_illuminating:
# education_topic_illuminating
# 0    18724
# 1      285
# Name: count, dtype: int64
#
# • engagement_cta_subtype_illuminating:
# engagement_cta_subtype_illuminating
# 0    17282
# 1     1727
# Name: count, dtype: int64
#
# • environment_topic_illuminating:
# environment_topic_illuminating
# 0    18586
# 1      423
# Name: count, dtype: int64
#
# • foreign_policy_topic_illuminating:
# foreign_policy_topic_illuminating
# 0    18308
# 1      701
# Name: count, dtype: int64
#
# • fraud_illuminating:
# fraud_illuminating
# 0    18845
# 1      164
# Name: count, dtype: int64
#
# • freefair_illuminating:
# freefair_illuminating
# 0    18955
# 1       54
# Name: count, dtype: int64
#
# • fundraising_cta_subtype_illuminating:
# fundraising_cta_subtype_illuminating
# 0    18659
# 1      350
# Name: count, dtype: int64
#
# • governance_topic_illuminating:
# governance_topic_illuminating
# 0    18418
# 1      591
# Name: count, dtype: int64
#
# • health_topic_illuminating:
# health_topic_illuminating
# 0    18084
# 1      925
# Name: count, dtype: int64
#
# • image_msg_type_illuminating:
# image_msg_type_illuminating
# 0    16185
# 1     2824
# Name: count, dtype: int64
#
# • immigration_topic_illuminating:
# immigration_topic_illuminating
# 0    18233
# 1      776
# Name: count, dtype: int64
#
# • incivility_illuminating:
# incivility_illuminating
# 0    16578
# 1     2431
# Name: count, dtype: int64
#
# • issue_msg_type_illuminating:
# issue_msg_type_illuminating
# 0    10259
# 1     8750
# Name: count, dtype: int64
#
# • lgbtq_issues_topic_illuminating:
# lgbtq_issues_topic_illuminating
# 0    18945
# 1       64
# Name: count, dtype: int64
#
# • military_topic_illuminating:
# military_topic_illuminating
# 0    18903
# 1      106
# Name: count, dtype: int64
#
# • race_and_ethnicity_topic_illuminating:
# race_and_ethnicity_topic_illuminating
# 0    18599
# 1      410
# Name: count, dtype: int64
#
# • safety_topic_illuminating:
# safety_topic_illuminating
# 0    18397
# 1      612
# Name: count, dtype: int64
#
# • scam_illuminating:
# scam_illuminating
# 0.0    17695
# 1.0      365
# Name: count, dtype: int64
#
# • social_and_cultural_topic_illuminating:
# social_and_cultural_topic_illuminating
# 0    17836
# 1     1173
# Name: count, dtype: int64
#
# • technology_and_privacy_topic_illuminating:
# technology_and_privacy_topic_illuminating
# 0    18970
# 1       39
# Name: count, dtype: int64
#
# • voting_cta_subtype_illuminating:
# voting_cta_subtype_illuminating
# 0    18564
# 1      445
# Name: count, dtype: int64
#
# • womens_issue_topic_illuminating:
# womens_issue_topic_illuminating
# 0    18525
# 1      484
# Name: count, dtype: int64
#
#
# 📊 Summary Report for: Twitter Posts
#
# 📈 Descriptive Statistics:
#                                                        id  \
# count                                               27304
# unique                                              27304
# top     cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       url           source  \
# count                                               27304            27304
# unique                                              27304               14
# top     f70a206472e9deaf6e313297c1efb891729ced346a0aeb...  Twitter Web App
# freq                                                    1            14930
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#          retweetCount     replyCount      likeCount     quoteCount  \
# count    27304.000000   27304.000000   27304.000000   27304.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean      1322.055193    1063.785013    6913.692829     128.081563
# std       3405.004240    3174.981654   21590.307989    1131.533468
# min          0.000000       0.000000       0.000000       0.000000
# 25%         84.000000      43.000000     393.000000       5.000000
# 50%        333.000000     131.000000    1406.000000      17.000000
# 75%       1071.000000     501.250000    5010.000000      69.000000
# max     144615.000000  121270.000000  915221.000000  123320.000000
#
#            viewCount            createdAt   lang  ...  \
# count   2.730400e+04                27304  27304  ...
# unique           NaN                27014     12  ...
# top              NaN  2023-10-06 04:55:21     en  ...
# freq             NaN                    4  27281  ...
# mean    5.070847e+05                  NaN    NaN  ...
# std     3.212174e+06                  NaN    NaN  ...
# min     5.000000e+00                  NaN    NaN  ...
# 25%     2.785275e+04                  NaN    NaN  ...
# 50%     7.094200e+04                  NaN    NaN  ...
# 75%     3.036630e+05                  NaN    NaN  ...
# max     3.335028e+08                  NaN    NaN  ...
#
#         military_topic_illuminating race_and_ethnicity_topic_illuminating  \
# count                  26034.000000                          26034.000000
# unique                          NaN                                   NaN
# top                             NaN                                   NaN
# freq                            NaN                                   NaN
# mean                       0.010986                              0.015403
# std                        0.104237                              0.123151
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        0.000000                              0.000000
# 75%                        0.000000                              0.000000
# max                        1.000000                              1.000000
#
#        safety_topic_illuminating social_and_cultural_topic_illuminating  \
# count               26034.000000                           26034.000000
# unique                       NaN                                    NaN
# top                          NaN                                    NaN
# freq                         NaN                                    NaN
# mean                    0.037605                               0.051971
# std                     0.190242                               0.221972
# min                     0.000000                               0.000000
# 25%                     0.000000                               0.000000
# 50%                     0.000000                               0.000000
# 75%                     0.000000                               0.000000
# max                     1.000000                               1.000000
#
#        technology_and_privacy_topic_illuminating  \
# count                               26034.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                    0.002036
# std                                     0.045075
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                      26034.000000             26034.000000
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                           0.023316                 0.178574
# std                            0.150907                 0.383003
# min                            0.000000                 0.000000
# 25%                            0.000000                 0.000000
# 50%                            0.000000                 0.000000
# 75%                            0.000000                 0.000000
# max                            1.000000                 1.000000
#
#        scam_illuminating freefair_illuminating  fraud_illuminating
# count       26034.000000          27304.000000        27304.000000
# unique               NaN                   NaN                 NaN
# top                  NaN                   NaN                 NaN
# freq                 NaN                   NaN                 NaN
# mean            0.012368              0.001428            0.002747
# std             0.110526              0.037767            0.052339
# min             0.000000              0.000000            0.000000
# 25%             0.000000              0.000000            0.000000
# 50%             0.000000              0.000000            0.000000
# 75%             0.000000              0.000000            0.000000
# max             1.000000              1.000000            1.000000
#
# [11 rows x 47 columns]
#
# 🔍 Unique Values per Column:
# id                                           27304
# url                                          27304
# source                                          14
# retweetCount                                  5197
# replyCount                                    4517
# likeCount                                    10202
# quoteCount                                    1346
# viewCount                                    25369
# createdAt                                    27014
# lang                                            12
# bookmarkCount                                 1440
# isReply                                          2
# isRetweet                                        1
# isQuote                                          2
# isConversationControlled                         2
# quoteId                                       3159
# inReplyToId                                   3309
# month_year                                      15
# illuminating_scored_message                  27136
# election_integrity_Truth_illuminating            2
# advocacy_msg_type_illuminating                   2
# issue_msg_type_illuminating                      2
# attack_msg_type_illuminating                     2
# image_msg_type_illuminating                      2
# cta_msg_type_illuminating                        2
# engagement_cta_subtype_illuminating              2
# fundraising_cta_subtype_illuminating             2
# voting_cta_subtype_illuminating                  2
# covid_topic_illuminating                         2
# economy_topic_illuminating                       2
# education_topic_illuminating                     2
# environment_topic_illuminating                   2
# foreign_policy_topic_illuminating                2
# governance_topic_illuminating                    2
# health_topic_illuminating                        2
# immigration_topic_illuminating                   2
# lgbtq_issues_topic_illuminating                  2
# military_topic_illuminating                      2
# race_and_ethnicity_topic_illuminating            2
# safety_topic_illuminating                        2
# social_and_cultural_topic_illuminating           2
# technology_and_privacy_topic_illuminating        2
# womens_issue_topic_illuminating                  2
# incivility_illuminating                          2
# scam_illuminating                                2
# freefair_illuminating                            2
# fraud_illuminating                               2
# dtype: int64
#
# 🏷️ Top 3 Most Frequent Values (Text Columns):
#
# id:
# id
# cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d    1
# e4272c39690914de8078c85eb45bbea8517796ee8fb2572007632a0a475136cd    1
# 75ef0d9a2893b5e3903d73cf1213d4f10849748195a8f70f16e0d6b375f49def    1
# Name: count, dtype: int64
#
# url:
# url
# f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937    1
# 5e5fc12720329a7fdfee7e59e57971a432565f1d9af04c35d4b1b934cd13d571    1
# 70638604f38d8aadb4f22a6cad9a846c5c9970d37702c79ed59f92793dcf6a31    1
# Name: count, dtype: int64
#
# source:
# source
# Twitter Web App       14930
# Twitter for iPhone     8494
# Sprout Social          2933
# Name: count, dtype: int64
#
# createdAt:
# createdAt
# 2023-10-06 04:55:21    4
# 2024-05-28 17:19:24    4
# 2024-08-30 03:04:08    4
# Name: count, dtype: int64
#
# lang:
# lang
# en    27281
# fr        6
# tl        4
# Name: count, dtype: int64
#
# month_year:
# month_year
# 2024-10    3586
# 2024-09    2856
# 2024-08    2647
# Name: count, dtype: int64
#
# illuminating_scored_message:
# illuminating_scored_message
# 36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd    21
# 1d2cc25fad0d66a295d4fafdd590d71d0e027a1d2a58cf5db0c58ba09b930e04    18
# e85b31153cfcc753f8657eb033c8e8fb03f6da4c384da1d4e563eef696f6e7a0    10
# Name: count, dtype: int64
#
# 📘 Analyzing Shared Columns in: Twitter Posts
#
# 📈 Numeric Summary (mean, median, min, max, std):
#                                                mean  50%  min  max       std
# advocacy_msg_type_illuminating             0.563686  1.0  0.0  1.0  0.495937
# attack_msg_type_illuminating               0.307598  0.0  0.0  1.0  0.461508
# covid_topic_illuminating                   0.007605  0.0  0.0  1.0  0.086879
# cta_msg_type_illuminating                  0.109664  0.0  0.0  1.0  0.312477
# economy_topic_illuminating                 0.160214  0.0  0.0  1.0  0.366811
# education_topic_illuminating               0.018437  0.0  0.0  1.0  0.134529
# engagement_cta_subtype_illuminating        0.066912  0.0  0.0  1.0  0.249875
# environment_topic_illuminating             0.028540  0.0  0.0  1.0  0.166512
# foreign_policy_topic_illuminating          0.042252  0.0  0.0  1.0  0.201168
# fraud_illuminating                         0.002747  0.0  0.0  1.0  0.052339
# freefair_illuminating                      0.001428  0.0  0.0  1.0  0.037767
# fundraising_cta_subtype_illuminating       0.007874  0.0  0.0  1.0  0.088389
# governance_topic_illuminating              0.022970  0.0  0.0  1.0  0.149811
# health_topic_illuminating                  0.055658  0.0  0.0  1.0  0.229264
# image_msg_type_illuminating                0.226435  0.0  0.0  1.0  0.418532
# immigration_topic_illuminating             0.065299  0.0  0.0  1.0  0.247058
# incivility_illuminating                    0.178574  0.0  0.0  1.0  0.383003
# issue_msg_type_illuminating                0.507682  1.0  0.0  1.0  0.499951
# lgbtq_issues_topic_illuminating            0.003073  0.0  0.0  1.0  0.055350
# military_topic_illuminating                0.010986  0.0  0.0  1.0  0.104237
# race_and_ethnicity_topic_illuminating      0.015403  0.0  0.0  1.0  0.123151
# safety_topic_illuminating                  0.037605  0.0  0.0  1.0  0.190242
# scam_illuminating                          0.012368  0.0  0.0  1.0  0.110526
# social_and_cultural_topic_illuminating     0.051971  0.0  0.0  1.0  0.221972
# technology_and_privacy_topic_illuminating  0.002036  0.0  0.0  1.0  0.045075
# voting_cta_subtype_illuminating            0.016786  0.0  0.0  1.0  0.128470
# womens_issue_topic_illuminating            0.023316  0.0  0.0  1.0  0.150907
#
# 🔍 Unique Value Counts:
# advocacy_msg_type_illuminating               2
# attack_msg_type_illuminating                 2
# covid_topic_illuminating                     2
# cta_msg_type_illuminating                    2
# economy_topic_illuminating                   2
# education_topic_illuminating                 2
# engagement_cta_subtype_illuminating          2
# environment_topic_illuminating               2
# foreign_policy_topic_illuminating            2
# fraud_illuminating                           2
# freefair_illuminating                        2
# fundraising_cta_subtype_illuminating         2
# governance_topic_illuminating                2
# health_topic_illuminating                    2
# image_msg_type_illuminating                  2
# immigration_topic_illuminating               2
# incivility_illuminating                      2
# issue_msg_type_illuminating                  2
# lgbtq_issues_topic_illuminating              2
# military_topic_illuminating                  2
# race_and_ethnicity_topic_illuminating        2
# safety_topic_illuminating                    2
# scam_illuminating                            2
# social_and_cultural_topic_illuminating       2
# technology_and_privacy_topic_illuminating    2
# voting_cta_subtype_illuminating              2
# womens_issue_topic_illuminating              2
# dtype: int64
#
# 🏷️ Top 3 Frequent Entries:
# • advocacy_msg_type_illuminating:
# advocacy_msg_type_illuminating
# 1.0    14675
# 0.0    11359
# Name: count, dtype: int64
#
# • attack_msg_type_illuminating:
# attack_msg_type_illuminating
# 0.0    18026
# 1.0     8008
# Name: count, dtype: int64
#
# • covid_topic_illuminating:
# covid_topic_illuminating
# 0.0    25836
# 1.0      198
# Name: count, dtype: int64
#
# • cta_msg_type_illuminating:
# cta_msg_type_illuminating
# 0.0    23179
# 1.0     2855
# Name: count, dtype: int64
#
# • economy_topic_illuminating:
# economy_topic_illuminating
# 0.0    21863
# 1.0     4171
# Name: count, dtype: int64
#
# • education_topic_illuminating:
# education_topic_illuminating
# 0.0    25554
# 1.0      480
# Name: count, dtype: int64
#
# • engagement_cta_subtype_illuminating:
# engagement_cta_subtype_illuminating
# 0.0    24292
# 1.0     1742
# Name: count, dtype: int64
#
# • environment_topic_illuminating:
# environment_topic_illuminating
# 0.0    25291
# 1.0      743
# Name: count, dtype: int64
#
# • foreign_policy_topic_illuminating:
# foreign_policy_topic_illuminating
# 0.0    24934
# 1.0     1100
# Name: count, dtype: int64
#
# • fraud_illuminating:
# fraud_illuminating
# 0    27229
# 1       75
# Name: count, dtype: int64
#
# • freefair_illuminating:
# freefair_illuminating
# 0    27265
# 1       39
# Name: count, dtype: int64
#
# • fundraising_cta_subtype_illuminating:
# fundraising_cta_subtype_illuminating
# 0.0    25829
# 1.0      205
# Name: count, dtype: int64
#
# • governance_topic_illuminating:
# governance_topic_illuminating
# 0.0    25436
# 1.0      598
# Name: count, dtype: int64
#
# • health_topic_illuminating:
# health_topic_illuminating
# 0.0    24585
# 1.0     1449
# Name: count, dtype: int64
#
# • image_msg_type_illuminating:
# image_msg_type_illuminating
# 0.0    20139
# 1.0     5895
# Name: count, dtype: int64
#
# • immigration_topic_illuminating:
# immigration_topic_illuminating
# 0.0    24334
# 1.0     1700
# Name: count, dtype: int64
#
# • incivility_illuminating:
# incivility_illuminating
# 0.0    21385
# 1.0     4649
# Name: count, dtype: int64
#
# • issue_msg_type_illuminating:
# issue_msg_type_illuminating
# 1.0    13217
# 0.0    12817
# Name: count, dtype: int64
#
# • lgbtq_issues_topic_illuminating:
# lgbtq_issues_topic_illuminating
# 0.0    25954
# 1.0       80
# Name: count, dtype: int64
#
# • military_topic_illuminating:
# military_topic_illuminating
# 0.0    25748
# 1.0      286
# Name: count, dtype: int64
#
# • race_and_ethnicity_topic_illuminating:
# race_and_ethnicity_topic_illuminating
# 0.0    25633
# 1.0      401
# Name: count, dtype: int64
#
# • safety_topic_illuminating:
# safety_topic_illuminating
# 0.0    25055
# 1.0      979
# Name: count, dtype: int64
#
# • scam_illuminating:
# scam_illuminating
# 0.0    25712
# 1.0      322
# Name: count, dtype: int64
#
# • social_and_cultural_topic_illuminating:
# social_and_cultural_topic_illuminating
# 0.0    24681
# 1.0     1353
# Name: count, dtype: int64
#
# • technology_and_privacy_topic_illuminating:
# technology_and_privacy_topic_illuminating
# 0.0    25981
# 1.0       53
# Name: count, dtype: int64
#
# • voting_cta_subtype_illuminating:
# voting_cta_subtype_illuminating
# 0.0    25597
# 1.0      437
# Name: count, dtype: int64
#
# • womens_issue_topic_illuminating:
# womens_issue_topic_illuminating
# 0.0    25427
# 1.0      607
# Name: count, dtype: int64
#
#
# 🧾 Bonus Analysis: Trump Truths Dataset
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 87
#      84 print("\n🧾 Bonus Analysis: Trump Truths Dataset")
#      85 start = time.time()
# ---> 87 trump_df = pd.read_csv("Downloads/period_03/trump_truths_dataset.csv")
#      88 summarize_dataset(trump_df, "Trump Truths")
#      90 end = time.time()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Downloads/period_03/trump_truths_dataset.csv'
